# %%
import pandas as pd
import matplotlib.pyplot as plt
from Untitled import num_to_years
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-4260bd001437> in <module>
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 from Untitled import num_to_years
#
# ~\Downloads\Untitled.py in <module>
#      17   {
#      18    "cell_type": "code",
# ---> 19    "execution_count": null,
#      20    "id": "0b34e396-8514-48ce-b722-278ddc9a393e",
#      21    "metadata": {},
#
# NameError: name 'null' is not defined

# %%
X = pd.read_csv('credit_record.csv/application_record.csv')
y = pd.read_csv('credit_record.csv/credit_record.csv')

# %%
X.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
y.head()
# Out:
#         ID  MONTHS_BALANCE STATUS
# 0  5001711               0      X
# 1  5001711              -1      0
# 2  5001711              -2      0
# 3  5001711              -3      0
# 4  5001712               0      C

# %% [markdown]
# ## Tyding the date

# %%
def days_to_years(X):
    X['CLIENT_AGE'] = X['DAYS_BIRTH'].apply(num_to_years)
    X['JOB_SENIORITY'] = X['DAYS_EMPLOYED'].apply(num_to_years)
    return X

# %%
X = days_to_years(X)
X.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-ebd9f7e0b557> in <module>
# ----> 1 X = days_to_years(X)
#       2 X.head()
#
# <ipython-input-25-f8c3bbfc28ab> in days_to_years(X)
#       1 def days_to_years(X):
# ----> 2     X['CLIENT_AGE'] = X['DAYS_BIRTH'].apply(num_to_years)
#       3     X['JOB_SENIORITY'] = X['DAYS_EMPLOYED'].apply(num_to_years)
#       4     return X
#
# TypeError: 'NoneType' object is not subscriptable

# %%
X.hist(figsize=(20,20), bins=10, color='turquoise')
# Out:
# array([[<AxesSubplot:title={'center':'ID'}>,
#         <AxesSubplot:title={'center':'CNT_CHILDREN'}>,
#         <AxesSubplot:title={'center':'AMT_INCOME_TOTAL'}>],
#        [<AxesSubplot:title={'center':'DAYS_BIRTH'}>,
#         <AxesSubplot:title={'center':'DAYS_EMPLOYED'}>,
#         <AxesSubplot:title={'center':'FLAG_MOBIL'}>],
#        [<AxesSubplot:title={'center':'FLAG_WORK_PHONE'}>,
#         <AxesSubplot:title={'center':'FLAG_PHONE'}>,
#         <AxesSubplot:title={'center':'FLAG_EMAIL'}>],
#        [<AxesSubplot:title={'center':'CNT_FAM_MEMBERS'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ## Tyding the Data
